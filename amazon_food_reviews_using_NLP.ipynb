# %%
from nltk.corpus import stopwords
import string
 
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
l=[]
for i in range(1,5001):
    filename = 'C:/Users/jayac/Downloads/txt_reviews/review_{}.txt'.format(i)
    text=load_doc(filename)
    #tokens = clean_doc(text)
    #print(tokens)
    l.append(text)
#l.append(text)

# %%
l

# %%
l1=[]
d=[]
for i in l:
    #l1=[]
    a=i.split('\n')
    l1.append(a)
    d.append(l1)

# %%
l1

# %%
l1[0]
# Out:
# ['ProductId: B001E4KFG0',
#  'UserId: A3SGXH7AUHU8GW',
#  'ProfileName: delmartian',
#  'HelpfulnessNumerator: 1',
#  'HelpfulnessDenominator: 1',
#  'Score: 5',
#  'Time: 1303862400',
#  'ReviewSummary: Good Quality Dog Food',
#  'ReviewText: I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.',
#  '']

# %%
l1[0][0]
# Out:
# 'ProductId: B001E4KFG0'

# %%
pid = []
uid =[]
profile_name = []
HelpfulnessNumerator = []
HelpfulnessDenominator= []
score=[]
Time=[]
ReviewSummary=[]
ReviewText=[]
for i in range(0,len(l1)):
    pid.append(l1[i][0])
    uid.append(l1[i][1])
    profile_name.append(l1[i][2])
    HelpfulnessNumerator.append(l1[i][3])
    HelpfulnessDenominator.append(l1[i][4])
    score.append(l1[i][5])
    Time.append(l1[i][6])
    ReviewSummary.append(l1[i][7])
    ReviewText.append(l1[i][8])

# %%
import pandas as pd

# %%
df = pd.DataFrame({'product_id':pid,'user_id':uid,'profile_name':profile_name, 'HelpfulnessNumerator':HelpfulnessNumerator,'HelpfulnessDenominator':HelpfulnessDenominator,'score':score,'Time':Time,'ReviewSummary':ReviewSummary,'ReviewText':ReviewText})

# %%
df.head()
# Out:
#               product_id                 user_id  \
# 0  ProductId: B001E4KFG0  UserId: A3SGXH7AUHU8GW
# 1  ProductId: B00813GRG4  UserId: A1D87F6ZCVE5NK
# 2  ProductId: B000LQOCH0   UserId: ABXLMWJIXXAIN
# 3  ProductId: B000UA0QIQ  UserId: A395BORC6FGVXV
# 4  ProductId: B006K2ZZ7K  UserId: A1UQRSCLF8GW1T
#
#                                    profile_name     HelpfulnessNumerator  \
# 0                       ProfileName: delmartian  HelpfulnessNumerator: 1
# 1                           ProfileName: dll pa  HelpfulnessNumerator: 0
# 2  ProfileName: Natalia Corres "Natalia Corres"  HelpfulnessNumerator: 1
# 3                             ProfileName: Karl  HelpfulnessNumerator: 3
# 4    ProfileName: Michael D. Bigham "M. Wassir"  HelpfulnessNumerator: 0
#
#       HelpfulnessDenominator     score              Time  \
# 0  HelpfulnessDenominator: 1  Score: 5  Time: 1303862400
# 1  HelpfulnessDenominator: 0  Score: 1  Time: 1346976000
# 2  HelpfulnessDenominator: 1  Score: 4  Time: 1219017600
# 3  HelpfulnessDenominator: 3  Score: 2  Time: 1307923200
# 4  HelpfulnessDenominator: 0  Score: 5  Time: 1350777600
#
#                           ReviewSummary  \
# 0  ReviewSummary: Good Quality Dog Food
# 1      ReviewSummary: Not as Advertised
# 2  ReviewSummary: "Delight" says it all
# 3         ReviewSummary: Cough Medicine
# 4            ReviewSummary: Great taffy
#
#                                           ReviewText
# 0  ReviewText: I have bought several of the Vital...
# 1  ReviewText: Product arrived labeled as Jumbo S...
# 2  ReviewText: This is a confection that has been...
# 3  ReviewText: If you are looking for the secret ...
# 4  ReviewText: Great taffy at a great price.  The...

# %%
df.shape
# Out:
# (5000, 9)

# %%
df['product_id'] = df['product_id'].replace({'ProductId:':''},regex =True)
df['user_id'] = df['user_id'].replace({'UserId:':''},regex =True)
df['profile_name'] = df['profile_name'].replace({'ProfileName:':''},regex =True)
df['HelpfulnessNumerator'] = df['HelpfulnessNumerator'].replace({'HelpfulnessNumerator:':''},regex =True)
df['HelpfulnessDenominator'] = df['HelpfulnessDenominator'].replace({'HelpfulnessDenominator:':''},regex =True)
df['score'] = df['score'].replace({'Score:':''},regex =True)
df['Time'] = df['Time'].replace({'Time:':''},regex =True)
df['ReviewSummary'] = df['ReviewSummary'].replace({'ReviewSummary:':''},regex =True)
df['ReviewText'] = df['ReviewText'].replace({'ReviewText:':''},regex =True)

# %%
df.head()
# Out:
#     product_id          user_id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#   HelpfulnessNumerator HelpfulnessDenominator score         Time  \
# 0                    1                      1     5   1303862400
# 1                    0                      0     1   1346976000
# 2                    1                      1     4   1219017600
# 3                    3                      3     2   1307923200
# 4                    0                      0     5   1350777600
#
#             ReviewSummary                                         ReviewText
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...

# %%
df.isnull().sum()
# Out:
# product_id                0
# user_id                   0
# profile_name              0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# score                     0
# Time                      0
# ReviewSummary             0
# ReviewText                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              5000 non-null   object
#  1   user_id                 5000 non-null   object
#  2   profile_name            5000 non-null   object
#  3   HelpfulnessNumerator    5000 non-null   object
#  4   HelpfulnessDenominator  5000 non-null   object
#  5   score                   5000 non-null   object
#  6   Time                    5000 non-null   object
#  7   ReviewSummary           5000 non-null   object
#  8   ReviewText              5000 non-null   object
# dtypes: object(9)
# memory usage: 351.7+ KB

# %%
df['score']=df['score'].astype(int)
df['HelpfulnessNumerator']=df['HelpfulnessNumerator'].astype(int)
df['HelpfulnessDenominator']=df['HelpfulnessDenominator'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              5000 non-null   object
#  1   user_id                 5000 non-null   object
#  2   profile_name            5000 non-null   object
#  3   HelpfulnessNumerator    5000 non-null   int32
#  4   HelpfulnessDenominator  5000 non-null   int32
#  5   score                   5000 non-null   int32
#  6   Time                    5000 non-null   object
#  7   ReviewSummary           5000 non-null   object
#  8   ReviewText              5000 non-null   object
# dtypes: int32(3), object(6)
# memory usage: 293.1+ KB

# %%
df.describe()
# Out:
#        HelpfulnessNumerator  HelpfulnessDenominator        score
# count           5000.000000             5000.000000  5000.000000
# mean               1.580200                2.067200     4.150400
# std                5.584533                6.288672     1.326549
# min                0.000000                0.000000     1.000000
# 25%                0.000000                0.000000     4.000000
# 50%                0.000000                1.000000     5.000000
# 75%                2.000000                2.000000     5.000000
# max              187.000000              216.000000     5.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['score'].value_counts()
# Out:
# 5    3134
# 4     712
# 1     469
# 3     395
# 2     290
# Name: score, dtype: int64

# %%
ratings = df["score"].value_counts()
numbers = ratings.index
quantity = ratings.values

custom_colors = ["orange", "yellowgreen", 'tomato', "blue", "red"]
plt.figure(figsize=(10, 8))
plt.pie(quantity, labels=numbers, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of Amazon Product Ratings", fontsize=20)
plt.show()

# %%
sns.countplot(x='score', data=df)
# Out:
# <AxesSubplot:xlabel='score', ylabel='count'>

# %%
df.columns
# Out:
# Index(['product_id', 'user_id', 'profile_name', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'score', 'Time', 'ReviewSummary',
#        'ReviewText'],
#       dtype='object')

# %%
#checking unique values in helpfulnessdenominator
df.HelpfulnessDenominator.unique()
# Out:
# array([  1,   0,   3,   4,   2,   5,  19,  13,   9,   7,  15,   8,   6,
#         10,  47,  17,  14,  27,  12,  11,  21,  31,  18,  23, 168,  46,
#         30, 133,  16,  36,  25,  26,  24,  22,  29,  20,  64, 216,  33,
#        112, 108,  51,  37,  39,  89,  35,  43])

# %%
# checking unique values
df.HelpfulnessDenominator.unique()
# Out:
# array([  1,   0,   3,   4,   2,   5,  19,  13,   9,   7,  15,   8,   6,
#         10,  47,  17,  14,  27,  12,  11,  21,  31,  18,  23, 168,  46,
#         30, 133,  16,  36,  25,  26,  24,  22,  29,  20,  64, 216,  33,
#        112, 108,  51,  37,  39,  89,  35,  43])

# %%
# copying the data frame to df1 so that original dataframe remain same 
df1 = df.copy()

# %%
# checking null values
df1.HelpfulnessDenominator.isnull().sum()
# Out:
# 0

# %%
df1.HelpfulnessDenominator.isnull().sum()
# Out:
# 0

# %%
# checking unique values of score
df1.score.unique()
# Out:
# array([5, 1, 4, 2, 3])

# %%
# checking the score count which is greater than 5
df1[df1.score > 5]['score'].count()
# Out:
# 0

# %%
df1.score.value_counts(normalize=True)
# Out:
# 5    0.6268
# 4    0.1424
# 1    0.0938
# 3    0.0790
# 2    0.0580
# Name: score, dtype: float64

# %% [markdown]
# ## Distribution of Ratings

# %%
# plotting rating distribution
sns.countplot(df1.score)
# Out:
# C:\Users\jayac\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='score', ylabel='count'>

# %% [markdown]
# 5 star review constitute a large proportion(64%) of all reviews. The next most review is 4 star(14%) followed by 1 star(9%),3 star(7%) and finally 2 star(5%)

# %% [markdown]
# ## lets consider
# .Positive review (4-5 Rating)
#
# .Negative review (1-2 Rating)

# %%
# removing 3  score from dataframe
df2 = df1[df1.score != 3]

# %%
df2.score.value_counts()
# Out:
# 5    3134
# 4     712
# 1     469
# 2     290
# Name: score, dtype: int64

# %%
# mapping the positive and negative to Score based on condition
df2['Rating'] = df2.score.apply(lambda x :  'Positive'    if x == 5 or x == 4 else 'Negative')
# Out:
# C:\Users\jayac\AppData\Local\Temp/ipykernel_4048/1579216146.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Rating'] = df2.score.apply(lambda x :  'Positive'    if x == 5 or x == 4 else 'Negative')

# %%
df2.head()
# Out:
#     product_id          user_id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  score         Time  \
# 0                     1                       1      5   1303862400
# 1                     0                       0      1   1346976000
# 2                     1                       1      4   1219017600
# 3                     3                       3      2   1307923200
# 4                     0                       0      5   1350777600
#
#             ReviewSummary                                         ReviewText  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...
#
#      Rating
# 0  Positive
# 1  Negative
# 2  Positive
# 3  Negative
# 4  Positive

# %%
# checking the value_counts of Rating
df2.Rating.value_counts()
# Out:
# Positive    3846
# Negative     759
# Name: Rating, dtype: int64

# %%
# creating new df positive
positive = df2[df2.Rating == 'Positive']['ReviewText']

# %%
positive

# %%
# importing wordcloud library
from wordcloud import WordCloud, STOPWORDS

# %%
# importing stopwords
from nltk.corpus import stopwords

# %%
# joing the positive text
text_postive = ' '.join(positive)

# %%
# removing 'br' from text
cleaned_positve = ' '.join([word for word in text_postive.split()
                       if 'br' not in word])

# %%
# creating positive wordcloud
positive_wordcloud = WordCloud(stopwords = stopwords.words('english'),
                          background_color='White',
                          width=1600,
                          height=800).generate(cleaned_positve)

# %%
# plotting wordcount of positive text
plt.figure(1,figsize=(30,20))
plt.imshow(positive_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Popular words in Negative Reviews (1-2 Rating)

# %%
# creating negative dataframe
Negative = df2[df2.Rating == 'Negative']['ReviewText']

# %%
Negative

# %%
# joining and cleaning negative text
text_negative = ' '.join(Negative)
cleaned_negative = ' '.join([word for word in text_negative.split()
                       if 'br' not in word])

# %%
# creating negative wordcloud
negative_wordcloud = WordCloud(stopwords = stopwords.words('english'),
                          background_color='Black',
                          width=1600,
                          height=800).generate(cleaned_negative)

# %%
# plotting wordcloud
plt.figure(1,figsize=(30,20))
plt.imshow(negative_wordcloud)
plt.axis('off')
plt.show()

# %%
# creating Helpful
Helpful = df2.HelpfulnessNumerator/df2.HelpfulnessDenominator

# %%
Helpful = Helpful*100

# %%
Helpful

# %% [markdown]
# ## Divide this Helpful into four categories
# No Indication(not voted at all)
#
# Helpful reviews had more than 75% of voters find the review helpful
#
# Unhelpful reviews had less than 25% of voters find the review helpful
#
# Intermediate group of 25-75% helpfulness

# %%
# creating dataframe of helpful
Helpful = pd.DataFrame(Helpful)

# %%
# creating column in df helpful
Helpful.columns = ['Helpfullness']

# %%
# creating helpful_cat function to differentiate helpfulness
def helpful_cat(x):
    if x > 75:
        return 'Helpful'
    elif x < 25:
        return 'Unhelpful'
    elif x >= 25 and x <= 75:
        return 'Intermediate'
    else:
        return 'No indication'

# %%
# applying the function to helpful dataframe
Helpful['category'] = Helpful['Helpfullness'].apply(helpful_cat)

# %%
Helpful.head()
# Out:
#    Helpfullness       category
# 0         100.0        Helpful
# 1           NaN  No indication
# 2         100.0        Helpful
# 3         100.0        Helpful
# 4           NaN  No indication

# %%
# checking helpful category valuecount
Helpful.category.value_counts(normalize=True)
# Out:
# No indication    0.479479
# Helpful          0.357438
# Intermediate     0.092291
# Unhelpful        0.070793
# Name: category, dtype: float64

# %% [markdown]
# ## Distribution of Helpfulness

# %%
import numpy as np

# %%
# plotting distribution 0f helpfulness
height = Helpful.category.value_counts(normalize=True).values*100
bars = Helpful.category.value_counts(normalize=True).index
x_pos = np.arange(len(bars))

# Create bars with different colors
plt.bar(x_pos, height, color=['Orange', 'red', 'green', 'blue', 'cyan'])

# Create names on the x-axis
plt.xticks(x_pos, bars)

# Show graph
plt.show()

# %%
# copy df2 into df3
df3 = df2.copy()

# %%
# concat helpful and df3
df3 = pd.concat([df3,Helpful],axis = 1)

# %%
df3.head()
# Out:
#     product_id          user_id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  score         Time  \
# 0                     1                       1      5   1303862400
# 1                     0                       0      1   1346976000
# 2                     1                       1      4   1219017600
# 3                     3                       3      2   1307923200
# 4                     0                       0      5   1350777600
#
#             ReviewSummary                                         ReviewText  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...
#
#      Rating  Helpfullness       category
# 0  Positive         100.0        Helpful
# 1  Negative           NaN  No indication
# 2  Positive         100.0        Helpful
# 3  Negative         100.0        Helpful
# 4  Positive           NaN  No indication

# %%
# removing no indication from df3
df3 = df3[df3.category != 'No indication']

# %%
df3.shape
# Out:
# (2397, 12)

# %% [markdown]
# ###  How does rating affect Helpfulness?

# %%
sns.countplot(x='Rating', hue='category', order=["Positive", "Negative"], 
              hue_order=['Helpful', 'Intermediate', 'Unhelpful'], data=df3)
plt.xlabel('Rating')
plt.show()

# %% [markdown]
# As the rating becomes more positive, the reviews become more helpful (and less unhelpful).

# %% [markdown]
# ## Word Count

# %%
# importing regular expression library
import re

# %%
# creating wordcount function
def word_count(x):
    res = len(re.findall(r'\w+',x))
    return res

# %%
# applying the wordcount function reviewtext column
df1['Wordcount'] = df1.ReviewText.apply(word_count)

# %%
df1.head()
# Out:
#     product_id          user_id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  score         Time  \
# 0                     1                       1      5   1303862400
# 1                     0                       0      1   1346976000
# 2                     1                       1      4   1219017600
# 3                     3                       3      2   1307923200
# 4                     0                       0      5   1350777600
#
#             ReviewSummary                                         ReviewText  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...
#
#    Wordcount
# 0         48
# 1         32
# 2         93
# 3         41
# 4         27

# %% [markdown]
# ### How does word count vary by rating?

# %%
# plotting word count v/s score 
plt.figure(figsize=(8,5))
sns.boxplot(x = 'score',y = 'Wordcount',data = df1, showfliers=False)
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %% [markdown]
# 5-star reviews had the lowest median word count (53 words), while 3-star reviews had the largest median word count (71 words).

# %%
# applying word count function to datframe df3 review text
df3['Wordcount'] = df3.ReviewText.apply(word_count)

# %% [markdown]
# ### How does word count relate to helpfulness?

# %%
# plotting wordcount v/s helpfulness
plt.figure(figsize=(8,5))
sns.violinplot(x = 'category',y = 'Wordcount',data = df3,gridsize=500,inner='quartile')
plt.ylim(0,300)
plt.show()

# %% [markdown]
# Helpful reviews have a higher median word count (67 words) than not helpful reviews (54 words) and intermediate have almost same as helpful.

# %% [markdown]
# ### Frequency of reviewers

# %%
# creating dictionary of userid valuecounts
x = df1.user_id.value_counts()
x.to_dict()
print(x)

# %%
# applying the frequency to userid
df1['reviewerfrequency'] = df1.user_id.apply(lambda index :  "Frequent" if x[index] > 5 else "Not Frequent")

# %%
df1.head()
# Out:
#     product_id          user_id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  score         Time  \
# 0                     1                       1      5   1303862400
# 1                     0                       0      1   1346976000
# 2                     1                       1      4   1219017600
# 3                     3                       3      2   1307923200
# 4                     0                       0      5   1350777600
#
#             ReviewSummary                                         ReviewText  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...
#
#    Wordcount reviewerfrequency
# 0         48      Not Frequent
# 1         32      Not Frequent
# 2         93      Not Frequent
# 3         41      Not Frequent
# 4         27      Not Frequent

# %% [markdown]
# ### Are frequent reviewers more discerning?

# %%
# plotting countplot of score with hue reviewer frequency
sns.countplot(x = 'score',data = df1,hue = 'reviewerfrequency')
# Out:
# <AxesSubplot:xlabel='score', ylabel='count'>

# %% [markdown]
# The frequent reviewers give less 5-star reviews and less 1-star review. Frequent users appear to be more discerning in the sense that they give less extreme reviews than infrequent reviews

# %%
x = df3.user_id.value_counts()
x.to_dict()
print(x)

# %%
df3['reviewerfrequency'] = df3.user_id.apply(lambda index :  "Frequent" if x[index] > 3 else "Not Frequent")

# %%
df3.head()
# Out:
#      product_id          user_id                      profile_name  \
# 0    B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 2    B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3    B000UA0QIQ   A395BORC6FGVXV                              Karl
# 8    B000E7L2R4   A1MZYO9TZK0BBI                          R. James
# 10   B0001PB9FE   A3HDKO7OW0QNK4                      Canadian Fan
#
#     HelpfulnessNumerator  HelpfulnessDenominator  score         Time  \
# 0                      1                       1      5   1303862400
# 2                      1                       1      4   1219017600
# 3                      3                       3      2   1307923200
# 8                      1                       1      5   1322006400
# 10                     1                       1      5   1107820800
#
#                        ReviewSummary  \
# 0              Good Quality Dog Food
# 2              "Delight" says it all
# 3                     Cough Medicine
# 8                         Yay Barley
# 10   The Best Hot Sauce in the World
#
#                                            ReviewText    Rating  Helpfullness  \
# 0    I have bought several of the Vitality canned ...  Positive         100.0
# 2    This is a confection that has been around a f...  Positive         100.0
# 3    If you are looking for the secret ingredient ...  Negative         100.0
# 8    Right now I'm mostly just sprouting this so m...  Positive         100.0
# 10   I don't know if it's the cactus or the tequil...  Positive         100.0
#
#    category  Wordcount reviewerfrequency
# 0   Helpful         48      Not Frequent
# 2   Helpful         93      Not Frequent
# 3   Helpful         41      Not Frequent
# 8   Helpful         27      Not Frequent
# 10  Helpful        154      Not Frequent

# %% [markdown]
# ### Are frequent reviewers more helpful?

# %%
# creating count plot of helpfulness with hue of reviewerfrequency
sns.countplot(x = 'category',data = df3,hue = 'reviewerfrequency')
# Out:
# <AxesSubplot:xlabel='category', ylabel='count'>

# %% [markdown]
# frequent reviewers are more likely to have their review voted on and when voted on more likely to be voted helpful, and less likely to be unhelpful

# %% [markdown]
# ### Are frequent reviewers more verbose?

# %%
# create violinplot of reviewerfrequency v/s word count
plt.figure(figsize=(8,5))
sns.violinplot(x = 'reviewerfrequency',y = 'Wordcount',data = df3,gridsize=500,inner='quartile')
plt.ylim(0,600)
plt.show()

# %% [markdown]
# The distributions of word counts for frequent and infrequent reviews shows that infrequent reviewers have a large amount of reviews of low word count. On the other hand, the largest concentration of word count is higher for frequent reviewers than for infrequent reviews. Moreover, the median word count for frequent reviewers is higher than the median for infrequent reviewers

# %% [markdown]
# ## conclusion
# .Positive reviews are very common.
#
# .Positive reviews are shorter.
#
# .Longer reviews are more helpful.
#
# .Despite being more common and shorter, positive reviews are found more helpful.
#
# .Frequent reviewers are more discerning in their ratings, write longer reviews, and write more helpful reviews

# %% [markdown]
# ## Modelling

# %%
df2.head()
# Out:
#     product_id          user_id                      profile_name  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  score         Time  \
# 0                     1                       1      5   1303862400
# 1                     0                       0      1   1346976000
# 2                     1                       1      4   1219017600
# 3                     3                       3      2   1307923200
# 4                     0                       0      5   1350777600
#
#             ReviewSummary                                         ReviewText  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# 1       Not as Advertised   Product arrived labeled as Jumbo Salted Peanu...
# 2   "Delight" says it all   This is a confection that has been around a f...
# 3          Cough Medicine   If you are looking for the secret ingredient ...
# 4             Great taffy   Great taffy at a great price.  There was a wi...
#
#      Rating
# 0  Positive
# 1  Negative
# 2  Positive
# 3  Negative
# 4  Positive

# %%
df2.shape
# Out:
# (4605, 10)

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(raw_text,flag):
    # Removing special character and digits
    sentence = re.sub("[^a-zA-Z]"," ",raw_text)
    
    # change sentence to lower case
    sentence = sentence.lower()
    
    # tokenize into words
    tokens = sentence.split()
    
    # remove stop words
    clean_tokens = [t for t in tokens if not t in stopwords.words('english')]
    
    # stemming/lemmitization
    
    if flag == 'stem':
        clean_tokens = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens),len(clean_tokens)])

# %%
X = df2[['ReviewText']]

# %%
y = df2['Rating']

# %%
from tqdm import tqdm, tqdm_notebook

# %%
tqdm.pandas()

# %%
temp_df = X['ReviewText'].progress_apply(lambda x : preprocess(x,'stem'))
# Out:
# 100%|██████████| 4605/4605 [01:16<00:00, 60.14it/s]

# %%
temp_df.head()
# Out:
#                                                    0   1
# 0  bought sever vital can dog food product found ...  23
# 1  product arriv label jumbo salt peanut peanut a...  18
# 2  confect around centuri light pillowi citru gel...  40
# 3  look secret ingredi robitussin believ found go...  18
# 4  great taffi great price wide assort yummi taff...  13

# %%
temp_df.columns = ['clean_text_stem','text_length_stem']
temp_df.head()
# Out:
#                                      clean_text_stem  text_length_stem
# 0  bought sever vital can dog food product found ...                23
# 1  product arriv label jumbo salt peanut peanut a...                18
# 2  confect around centuri light pillowi citru gel...                40
# 3  look secret ingredi robitussin believ found go...                18
# 4  great taffi great price wide assort yummi taff...                13

# %%
X = pd.concat([X,temp_df],axis = 1)
X.head()
# Out:
#                                           ReviewText  \
# 0   I have bought several of the Vitality canned ...
# 1   Product arrived labeled as Jumbo Salted Peanu...
# 2   This is a confection that has been around a f...
# 3   If you are looking for the secret ingredient ...
# 4   Great taffy at a great price.  There was a wi...
#
#                                      clean_text_stem  text_length_stem
# 0  bought sever vital can dog food product found ...                23
# 1  product arriv label jumbo salt peanut peanut a...                18
# 2  confect around centuri light pillowi citru gel...                40
# 3  look secret ingredi robitussin believ found go...                18
# 4  great taffi great price wide assort yummi taff...                13

# %%
temp_df = X['ReviewText'].progress_apply(lambda x : preprocess(x,'lemma'))
# Out:
# 100%|██████████| 4605/4605 [01:15<00:00, 61.21it/s]

# %%
temp_df.columns = ['clean_text_lemma','text_length_lemma']
temp_df.head()
# Out:
#                                     clean_text_lemma  text_length_lemma
# 0  bought several vitality canned dog food produc...                 23
# 1  product arrived labeled jumbo salted peanut pe...                 18
# 2  confection around century light pillowy citrus...                 40
# 3  looking secret ingredient robitussin believe f...                 18
# 4  great taffy great price wide assortment yummy ...                 13

# %%
X = pd.concat([X,temp_df],axis = 1)

X.head()
# Out:
#                                           ReviewText  \
# 0   I have bought several of the Vitality canned ...
# 1   Product arrived labeled as Jumbo Salted Peanu...
# 2   This is a confection that has been around a f...
# 3   If you are looking for the secret ingredient ...
# 4   Great taffy at a great price.  There was a wi...
#
#                                      clean_text_stem  text_length_stem  \
# 0  bought sever vital can dog food product found ...                23
# 1  product arriv label jumbo salt peanut peanut a...                18
# 2  confect around centuri light pillowi citru gel...                40
# 3  look secret ingredi robitussin believ found go...                18
# 4  great taffi great price wide assort yummi taff...                13
#
#                                     clean_text_lemma  text_length_lemma
# 0  bought several vitality canned dog food produc...                 23
# 1  product arrived labeled jumbo salted peanut pe...                 18
# 2  confection around century light pillowy citrus...                 40
# 3  looking secret ingredient robitussin believe f...                 18
# 4  great taffy great price wide assortment yummy ...                 13

# %%
X.isnull().sum()
# Out:
# ReviewText           0
# clean_text_stem      0
# text_length_stem     0
# clean_text_lemma     0
# text_length_lemma    0
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer

vocab = CountVectorizer()
vocab.fit(X['clean_text_lemma'])
X_bow = vocab.transform(X['clean_text_lemma'])

# %%
print('Toral unique words:', len(vocab.vocabulary_))
print('Type of train features:', type(X_bow))
print('shape of input data:', X_bow.shape)
# Out:
# Toral unique words: 11048
# Type of train features: <class 'scipy.sparse.csr.csr_matrix'>
# shape of input data: (4605, 11048)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train_bow,X_test_bow,y_train_bow,y_test_bow = train_test_split(X_bow,y,test_size=0.2,random_state=42)

# %%
X_train_bow.shape
# Out:
# (3684, 11048)

# %%
X_test_bow.shape
# Out:
# (921, 11048)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_bow,y_train_bow)
# Out:
# LogisticRegression()

# %%
y_test_bow_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test_bow,y_test_bow_pred))

print(classification_report(y_test_bow,y_test_bow_pred))
# Out:
# 0.8914223669923995
#               precision    recall  f1-score   support
#
#     Negative       0.73      0.50      0.60       147
#     Positive       0.91      0.97      0.94       774
#
#     accuracy                           0.89       921
#    macro avg       0.82      0.73      0.77       921
# weighted avg       0.88      0.89      0.88       921

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_bow,y_train_bow)
# Out:
# DecisionTreeClassifier()

# %%
y_test_bow_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test_bow,y_test_bow_pred))

print(classification_report(y_test_bow,y_test_bow_pred))
# Out:
# 0.8154180238870793
#               precision    recall  f1-score   support
#
#     Negative       0.41      0.36      0.38       147
#     Positive       0.88      0.90      0.89       774
#
#     accuracy                           0.82       921
#    macro avg       0.65      0.63      0.64       921
# weighted avg       0.81      0.82      0.81       921

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_bow,y_train_bow)
# Out:
# RandomForestClassifier()

# %%
y_test_bow_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test_bow,y_test_bow_pred))

print(classification_report(y_test_bow,y_test_bow_pred))
# Out:
# 0.8621064060803475
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.15      0.26       147
#     Positive       0.86      1.00      0.92       774
#
#     accuracy                           0.86       921
#    macro avg       0.89      0.57      0.59       921
# weighted avg       0.87      0.86      0.82       921
